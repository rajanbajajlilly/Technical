# %%
import pandas as pd
from pandas_datareader import data
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # User the plot method to render a line chart

# %%
bb = data.DataReader(name = "BB", data_source = "yahoo", start = "2007-01-01", end = "2020-12-31")
bb.head(3)
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2007-01-03  44.026669  41.703335  43.086666  42.849998  34739100.0  42.849998
# 2007-01-04  46.316666  42.423332  42.953335  46.189999  46007700.0  46.189999
# 2007-01-05  47.306667  45.166668  45.500000  47.099998  41453400.0  47.099998

# %%
bb.plot()

# %%
bb.plot(y = "Volume")

# %%
bb.plot(y = "High")

# %%
bb["High"]
# Out:
# Date
# 2007-01-03    44.026669
# 2007-01-04    46.316666
# 2007-01-05    47.306667
# 2007-01-08    48.410000
# 2007-01-09    47.666668
#                 ...
# 2020-07-29     4.910000
# 2020-07-30     4.830000
# 2020-07-31     4.780000
# 2020-08-03     4.750000
# 2020-08-04     4.761400
# Name: High, Length: 3421, dtype: float64

# %%
bb["High"].plot()

# %%
bb[["High", "Close"]].plot()

# %% [markdown]
# # Modifying plot asthetics with matplotlib templates

# %%
plt.style.available
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2',
#  'tableau-colorblind10',
#  '_classic_test']

# %%
plt.style.use("fivethirtyeight")
bb.plot(y = ["Close", "High"])

# %%
plt.style.use("dark_background")
bb.plot(y = ["Close", "High"])

# %%
plt.style.use("ggplot")
bb.plot(y = ["Close"])

# %% [markdown]
# # Creating bar graphs to show counts

# %%
def rank_performance(stock_price):
    if stock_price <= 10:
        return "Poor"
    elif stock_price <=50:
        return "Satisfactory"
    else:
        return "Stellar"

# %%
bb["Close"].apply(rank_performance)
# Out:
# Date
# 2007-01-03    Satisfactory
# 2007-01-04    Satisfactory
# 2007-01-05    Satisfactory
# 2007-01-08    Satisfactory
# 2007-01-09    Satisfactory
#                   ...
# 2020-07-29            Poor
# 2020-07-30            Poor
# 2020-07-31            Poor
# 2020-08-03            Poor
# 2020-08-04            Poor
# Name: Close, Length: 3421, dtype: object

# %%
bb["Close"].apply(rank_performance).value_counts()
# Out:
# Poor            1437
# Satisfactory    1125
# Stellar          859
# Name: Close, dtype: int64

# %%
bb["Close"].apply(rank_performance).value_counts().plot()

# %%
bb["Close"].apply(rank_performance).value_counts().plot(kind = "line")

# %%
bb["Close"].apply(rank_performance).value_counts().plot(kind = "bar")

# %%
bb["Close"].apply(rank_performance).value_counts().plot(kind = "barh") #bar horizontal

# %%
bb["Close"].apply(rank_performance).value_counts().plot(kind = "pie") #bar horizontal

# %% [markdown]
# # Creating pie charts to represetn proportions

# %%
bb["Close"].mean()
# Out:
# 30.180331295674673

# %%
def rank_performance(stock_price):
    if stock_price >= 30.180331295674673:
        return "Above Average"
    else:
        return "Below Average"

# %%
bb["Close"].apply(rank_performance).value_counts()
# Out:
# Below Average    2291
# Above Average    1130
# Name: Close, dtype: int64

# %%
plt.style.use("dark_background")
bb["Close"].apply(rank_performance).value_counts().plot(kind = "pie")

# %%
plt.style.use("dark_background")
bb["Close"].apply(rank_performance).value_counts().plot(kind = "pie", legend = True)
