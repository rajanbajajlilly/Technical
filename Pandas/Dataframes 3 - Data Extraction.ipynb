# %%
import pandas as pd

# %%
pd.read_csv('jamesbond.csv')
# Out:
#                                Film  Year           Actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 4                     Casino Royale  1967     David Niven          Ken Hughes
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# ...

# %%
bond = pd.read_csv('jamesbond.csv', index_col = 'Film')

# %%
bond.head(3)
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2

# %%
bond = pd.read_csv('jamesbond.csv')

# %%
bond.set_index(keys = 'Film', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-b1a7ada00d40> in <module>
# ----> 1 bond.set_index(keys = 'Film', inplace=True)
#
# NameError: name 'bond' is not defined

# %%
bond.head(4)
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
# Thunderball            1965  Sean Connery  Terence Young       848.1    41.9
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Thunderball                          4.7

# %%
bond.reset_index()
# Out:
#                                Film  Year           Actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 4                     Casino Royale  1967     David Niven          Ken Hughes
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# ...

# %%
bond.reset_index(drop=True) #will drop the index which was earlier there
# Out:
#     Year           Actor            Director  Box Office  Budget  \
# 0   1962    Sean Connery       Terence Young       448.8     7.0
# 1   1963    Sean Connery       Terence Young       543.8    12.6
# 2   1964    Sean Connery        Guy Hamilton       820.4    18.6
# 3   1965    Sean Connery       Terence Young       848.1    41.9
# 4   1967     David Niven          Ken Hughes       315.0    85.0
# 5   1967    Sean Connery       Lewis Gilbert       514.2    59.9
# 6   1969  George Lazenby       Peter R. Hunt       291.5    37.3
# 7   1971    Sean Connery        Guy Hamilton       442.5    34.7
# 8   1973     Roger Moore        Guy Hamilton       460.3    30.8
# 9   1974     Roger Moore        Guy Hamilton       334.0    27.7
# 10  1977     Roger Moore       Lewis Gilbert       533.0    45.1
# 11  1979     Roger Moore       Lewis Gilbert       535.0    91.5
# 12  1981     Roger Moore           John Glen       449.4    60.2
# ...

# %%
bond.head(4)
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
# Thunderball            1965  Sean Connery  Terence Young       848.1    41.9
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Thunderball                          4.7

# %%
bond.reset_index(drop = False)
# Out:
#                                Film  Year           Actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 4                     Casino Royale  1967     David Niven          Ken Hughes
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# ...

# %%
bond.reset_index(inplace=True)
bond.set_index('Year', inplace=True)

# %%
bond.head(4)
# Out:
#                        Film         Actor       Director  Box Office  Budget  \
# Year
# 1962                 Dr. No  Sean Connery  Terence Young       448.8     7.0
# 1963  From Russia with Love  Sean Connery  Terence Young       543.8    12.6
# 1964             Goldfinger  Sean Connery   Guy Hamilton       820.4    18.6
# 1965            Thunderball  Sean Connery  Terence Young       848.1    41.9
#
#       Bond Actor Salary
# Year
# 1962                0.6
# 1963                1.6
# 1964                3.2
# 1965                4.7

# %%
bond.reset_index()
# Out:
#     Year                             Film           Actor            Director  \
# 0   1962                           Dr. No    Sean Connery       Terence Young
# 1   1963            From Russia with Love    Sean Connery       Terence Young
# 2   1964                       Goldfinger    Sean Connery        Guy Hamilton
# 3   1965                      Thunderball    Sean Connery       Terence Young
# 4   1967                    Casino Royale     David Niven          Ken Hughes
# 5   1967              You Only Live Twice    Sean Connery       Lewis Gilbert
# 6   1969  On Her Majesty's Secret Service  George Lazenby       Peter R. Hunt
# 7   1971             Diamonds Are Forever    Sean Connery        Guy Hamilton
# 8   1973                 Live and Let Die     Roger Moore        Guy Hamilton
# 9   1974      The Man with the Golden Gun     Roger Moore        Guy Hamilton
# 10  1977             The Spy Who Loved Me     Roger Moore       Lewis Gilbert
# ...

# %%
bond.head(3)
# Out:
#                        Film         Actor       Director  Box Office  Budget  \
# Year
# 1962                 Dr. No  Sean Connery  Terence Young       448.8     7.0
# 1963  From Russia with Love  Sean Connery  Terence Young       543.8    12.6
# 1964             Goldfinger  Sean Connery   Guy Hamilton       820.4    18.6
#
#       Bond Actor Salary
# Year
# 1962                0.6
# 1963                1.6
# 1964                3.2

# %%
bond.reset_index(inplace=True)

# %%
bond.head(4)
# Out:
#    Year                   Film         Actor       Director  Box Office  \
# 0  1962                 Dr. No  Sean Connery  Terence Young       448.8
# 1  1963  From Russia with Love  Sean Connery  Terence Young       543.8
# 2  1964             Goldfinger  Sean Connery   Guy Hamilton       820.4
# 3  1965            Thunderball  Sean Connery  Terence Young       848.1
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2
# 3    41.9                4.7

# %%
bond = pd.read_csv('jamesbond.csv', index_col = 'Film')
bond.head(4)
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
# Thunderball            1965  Sean Connery  Terence Young       848.1    41.9
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Thunderball                          4.7

# %% [markdown]
# Retrieve rows of index label with .loc[] accessor

# %%
bond.sort_index(inplace=True)
bond.head(4)
# Out:
#                       Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill      1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale         2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale         1967   David Niven       Ken Hughes       315.0    85.0
# Diamonds Are Forever  1971  Sean Connery     Guy Hamilton       442.5    34.7
#
#                       Bond Actor Salary
# Film
# A View to a Kill                    9.1
# Casino Royale                       3.3
# Casino Royale                       NaN
# Diamonds Are Forever                5.8

# %%
bond.loc['Goldfinger'] #col names - index of the series, values - rows
# Out:
# Year                         1964
# Actor                Sean Connery
# Director             Guy Hamilton
# Box Office                  820.4
# Budget                       18.6
# Bond Actor Salary             3.2
# Name: Goldfinger, dtype: object

# %%
bond.loc['GoldenEye']
# Out:
# Year                            1995
# Actor                 Pierce Brosnan
# Director             Martin Campbell
# Box Office                     518.5
# Budget                          76.9
# Bond Actor Salary                5.1
# Name: GoldenEye, dtype: object

# %%
bond.loc['Casino Royale'] #if 1 row matches - series, >1 - dataframe
# Out:
#                Year         Actor         Director  Box Office  Budget  \
# Film
# Casino Royale  2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale  1967   David Niven       Ken Hughes       315.0    85.0
#
#                Bond Actor Salary
# Film
# Casino Royale                3.3
# Casino Royale                NaN

# %%
bond.loc['Diamonds Are Foreever':'From Russia with Love'] #list slices, last value inclusive
# Out:
#                        Year           Actor       Director  Box Office  \
# Film
# Diamonds Are Forever   1971    Sean Connery   Guy Hamilton       442.5
# Die Another Day        2002  Pierce Brosnan   Lee Tamahori       465.4
# Dr. No                 1962    Sean Connery  Terence Young       448.8
# For Your Eyes Only     1981     Roger Moore      John Glen       449.4
# From Russia with Love  1963    Sean Connery  Terence Young       543.8
#
#                        Budget  Bond Actor Salary
# Film
# Diamonds Are Forever     34.7                5.8
# Die Another Day         154.2               17.9
# Dr. No                    7.0                0.6
# For Your Eyes Only       60.2                NaN
# From Russia with Love    12.6                1.6

# %%
bond.loc['Diamonds Are Foreever':'From Russia with Love':2] #step size 2
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Diamonds Are Forever   1971  Sean Connery   Guy Hamilton       442.5    34.7
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
#
#                        Bond Actor Salary
# Film
# Diamonds Are Forever                 5.8
# Dr. No                               0.6
# From Russia with Love                1.6

# %%
bond.loc['GoldenEye':]
# Out:
#                                  Year           Actor            Director  \
# Film
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# Never Say Never Again            1983    Sean Connery      Irvin Kershner
# Octopussy                        1983     Roger Moore           John Glen
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Quantum of Solace                2008    Daniel Craig        Marc Forster
# Skyfall                          2012    Daniel Craig          Sam Mendes
# Spectre                          2015    Daniel Craig          Sam Mendes
# The Living Daylights             1987  Timothy Dalton           John Glen
# ...

# %%
bond.loc[:"On Her Majesty's Secret Service"]
# Out:
#                                  Year           Actor         Director  \
# Film
# A View to a Kill                 1985     Roger Moore        John Glen
# Casino Royale                    2006    Daniel Craig  Martin Campbell
# Casino Royale                    1967     David Niven       Ken Hughes
# Diamonds Are Forever             1971    Sean Connery     Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan     Lee Tamahori
# Dr. No                           1962    Sean Connery    Terence Young
# For Your Eyes Only               1981     Roger Moore        John Glen
# From Russia with Love            1963    Sean Connery    Terence Young
# GoldenEye                        1995  Pierce Brosnan  Martin Campbell
# Goldfinger                       1964    Sean Connery     Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton        John Glen
# Live and Let Die                 1973     Roger Moore     Guy Hamilton
# ...

# %%
bond.loc[['Die Another Day', 'Octopussy']] #multiple extraction using list
# Out:
#                  Year           Actor      Director  Box Office  Budget  \
# Film
# Die Another Day  2002  Pierce Brosnan  Lee Tamahori       465.4   154.2
# Octopussy        1983     Roger Moore     John Glen       373.8    53.9
#
#                  Bond Actor Salary
# Film
# Die Another Day               17.9
# Octopussy                      7.8

# %%
'Die Another Day' in bond.index
# Out:
# True

# %% [markdown]
# # Retrieve Rows by Index Position with iloc accessor

# %%
bond.head(4)
# Out:
#                       Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill      1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale         2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale         1967   David Niven       Ken Hughes       315.0    85.0
# Diamonds Are Forever  1971  Sean Connery     Guy Hamilton       442.5    34.7
#
#                       Bond Actor Salary
# Film
# A View to a Kill                    9.1
# Casino Royale                       3.3
# Casino Royale                       NaN
# Diamonds Are Forever                5.8

# %%
bond = pd.read_csv('jamesbond.csv')

# %%
bond.iloc[0]
# Out:
# Film                        Dr. No
# Year                          1962
# Actor                 Sean Connery
# Director             Terence Young
# Box Office                   448.8
# Budget                           7
# Bond Actor Salary              0.6
# Name: 0, dtype: object

# %%
bond.iloc[0:7]
# Out:
#                               Film  Year           Actor       Director  \
# 0                           Dr. No  1962    Sean Connery  Terence Young
# 1            From Russia with Love  1963    Sean Connery  Terence Young
# 2                       Goldfinger  1964    Sean Connery   Guy Hamilton
# 3                      Thunderball  1965    Sean Connery  Terence Young
# 4                    Casino Royale  1967     David Niven     Ken Hughes
# 5              You Only Live Twice  1967    Sean Connery  Lewis Gilbert
# 6  On Her Majesty's Secret Service  1969  George Lazenby  Peter R. Hunt
#
#    Box Office  Budget  Bond Actor Salary
# 0       448.8     7.0                0.6
# 1       543.8    12.6                1.6
# 2       820.4    18.6                3.2
# 3       848.1    41.9                4.7
# 4       315.0    85.0                NaN
# 5       514.2    59.9                4.4
# 6       291.5    37.3                0.6

# %%
bond.iloc[[15,20]]
# Out:
#                        Film  Year           Actor       Director  Box Office  \
# 15         A View to a Kill  1985     Roger Moore      John Glen       275.2
# 20  The World Is Not Enough  1999  Pierce Brosnan  Michael Apted       439.5
#
#     Budget  Bond Actor Salary
# 15    54.5                9.1
# 20   158.3               13.5

# %%
bond.iloc[4:8] #not including 8, big difference between iloc and loc
# Out:
#                               Film  Year           Actor       Director  \
# 4                    Casino Royale  1967     David Niven     Ken Hughes
# 5              You Only Live Twice  1967    Sean Connery  Lewis Gilbert
# 6  On Her Majesty's Secret Service  1969  George Lazenby  Peter R. Hunt
# 7             Diamonds Are Forever  1971    Sean Connery   Guy Hamilton
#
#    Box Office  Budget  Bond Actor Salary
# 4       315.0    85.0                NaN
# 5       514.2    59.9                4.4
# 6       291.5    37.3                0.6
# 7       442.5    34.7                5.8

# %%
bond.set_index('Film', inplace=True)
bond.sort_index(inplace=True)
bond.head(4)
# Out:
#                       Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill      1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale         2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale         1967   David Niven       Ken Hughes       315.0    85.0
# Diamonds Are Forever  1971  Sean Connery     Guy Hamilton       442.5    34.7
#
#                       Bond Actor Salary
# Film
# A View to a Kill                    9.1
# Casino Royale                       3.3
# Casino Royale                       NaN
# Diamonds Are Forever                5.8

# %%
bond.iloc[0]
# Out:
# Year                        1985
# Actor                Roger Moore
# Director               John Glen
# Box Office                 275.2
# Budget                      54.5
# Bond Actor Salary            9.1
# Name: A View to a Kill, dtype: object

# %%
bond.loc['Casino Royale']
# Out:
#                Year         Actor         Director  Box Office  Budget  \
# Film
# Casino Royale  2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale  1967   David Niven       Ken Hughes       315.0    85.0
#
#                Bond Actor Salary
# Film
# Casino Royale                3.3
# Casino Royale                NaN

# %%
bond.iloc[10:]
# Out:
#                                  Year           Actor            Director  \
# Film
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# Never Say Never Again            1983    Sean Connery      Irvin Kershner
# Octopussy                        1983     Roger Moore           John Glen
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Quantum of Solace                2008    Daniel Craig        Marc Forster
# Skyfall                          2012    Daniel Craig          Sam Mendes
# Spectre                          2015    Daniel Craig          Sam Mendes
# The Living Daylights             1987  Timothy Dalton           John Glen
# The Man with the Golden Gun      1974     Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977     Roger Moore       Lewis Gilbert
# ...

# %% [markdown]
# # Passing second argument to loc and iloc accessor

# %%
bond.head(4)
# Out:
#                       Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill      1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale         2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale         1967   David Niven       Ken Hughes       315.0    85.0
# Diamonds Are Forever  1971  Sean Connery     Guy Hamilton       442.5    34.7
#
#                       Bond Actor Salary
# Film
# A View to a Kill                    9.1
# Casino Royale                       3.3
# Casino Royale                       NaN
# Diamonds Are Forever                5.8

# %%
bond.loc['Moonraker']
# Out:
# Year                          1979
# Actor                  Roger Moore
# Director             Lewis Gilbert
# Box Office                     535
# Budget                        91.5
# Bond Actor Salary              NaN
# Name: Moonraker, dtype: object

# %%
bond.loc['Moonraker', 'Actor'] #column actor whatever value is there
# Out:
# 'Roger Moore'

# %%
bond.loc['Moonraker', 'Director']
# Out:
# 'Lewis Gilbert'

# %%
bond.loc['Moonraker', ['Box Office', 'Director']]
# Out:
# Box Office              535
# Director      Lewis Gilbert
# Name: Moonraker, dtype: object

# %%
bond.loc[['Moonraker','A View to a Kill'], ['Box Office', 'Director']]
# Out:
#                   Box Office       Director
# Film
# Moonraker              535.0  Lewis Gilbert
# A View to a Kill       275.2      John Glen

# %%
bond.loc['Moonraker', 'Director':'Budget'] #slicing
# Out:
# Director      Lewis Gilbert
# Box Office              535
# Budget                 91.5
# Name: Moonraker, dtype: object

# %%
bond.loc['Moonraker':'Thunderball', 'Director':'Budget'] #slicing on the index
# Out:
#                                        Director  Box Office  Budget
# Film
# Moonraker                         Lewis Gilbert       535.0    91.5
# Never Say Never Again            Irvin Kershner       380.0    86.0
# Octopussy                             John Glen       373.8    53.9
# On Her Majesty's Secret Service   Peter R. Hunt       291.5    37.3
# Quantum of Solace                  Marc Forster       514.2   181.4
# Skyfall                              Sam Mendes       943.5   170.2
# Spectre                              Sam Mendes       726.7   206.3
# The Living Daylights                  John Glen       313.5    68.8
# The Man with the Golden Gun        Guy Hamilton       334.0    27.7
# The Spy Who Loved Me              Lewis Gilbert       533.0    45.1
# The World Is Not Enough           Michael Apted       439.5   158.3
# Thunderball                       Terence Young       848.1    41.9

# %%
bond.loc['Moonraker':, 'Director':] #slicing on the index
# Out:
#                                            Director  Box Office  Budget  \
# Film
# Moonraker                             Lewis Gilbert       535.0    91.5
# Never Say Never Again                Irvin Kershner       380.0    86.0
# Octopussy                                 John Glen       373.8    53.9
# On Her Majesty's Secret Service       Peter R. Hunt       291.5    37.3
# Quantum of Solace                      Marc Forster       514.2   181.4
# Skyfall                                  Sam Mendes       943.5   170.2
# Spectre                                  Sam Mendes       726.7   206.3
# The Living Daylights                      John Glen       313.5    68.8
# The Man with the Golden Gun            Guy Hamilton       334.0    27.7
# The Spy Who Loved Me                  Lewis Gilbert       533.0    45.1
# The World Is Not Enough               Michael Apted       439.5   158.3
# Thunderball                           Terence Young       848.1    41.9
# ...

# %%
bond.iloc[14]
# Out:
# Year                        1983
# Actor                Roger Moore
# Director               John Glen
# Box Office                 373.8
# Budget                      53.9
# Bond Actor Salary            7.8
# Name: Octopussy, dtype: object

# %%
bond.iloc[14,2]
# Out:
# 'John Glen'

# %%
bond.iloc[14,2:5]
# Out:
# Director      John Glen
# Box Office        373.8
# Budget             53.9
# Name: Octopussy, dtype: object

# %%
bond.iloc[:7, [2,4]]
# Out:
#                              Director  Budget
# Film
# A View to a Kill            John Glen    54.5
# Casino Royale         Martin Campbell   145.3
# Casino Royale              Ken Hughes    85.0
# Diamonds Are Forever     Guy Hamilton    34.7
# Die Another Day          Lee Tamahori   154.2
# Dr. No                  Terence Young     7.0
# For Your Eyes Only          John Glen    60.2

# %% [markdown]
# # Set New Value for a Specific Cell

# %%
bond = pd.read_csv('jamesbond.csv', index_col = 'Film')
bond.sort_values(inplace = True)
bond.head(3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-36b652650a17> in <module>
#       1 bond = pd.read_csv('jamesbond.csv', index_col = 'Film')
# ----> 2 bond.sort_values(inplace = True)
#       3 bond.head(3)
#
# TypeError: sort_values() missing 1 required positional argument: 'by'

# %%
import pandas as pd

# %%
bond = pd.read_csv('jamesbond.csv', index_col = 'Film')
bond.sort_index(inplace = True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
bond.loc['Dr. No', 'Actor'] = 'Sir Sean Connery'

# %%
bond.loc['Dr. No']
# Out:
# Year                             1962
# Actor                Sir Sean Connery
# Director                Terence Young
# Box Office                      448.8
# Budget                              7
# Bond Actor Salary                 0.6
# Action               Sir Sean Connery
# Name: Dr. No, dtype: object

# %%
bond.loc['Dr. No', ['Box Office', 'Budget', 'Bond Actor Salary']]
# Out:
# Box Office           448.8
# Budget                   7
# Bond Actor Salary      0.6
# Name: Dr. No, dtype: object

# %%
bond.loc['Dr. No', ['Box Office', 'Budget', 'Bond Actor Salary']] = [448000000, 7000000, 6000000]

# %%
bond.loc['Dr. No', ['Box Office', 'Budget', 'Bond Actor Salary']]
# Out:
# Box Office           4.48e+08
# Budget                  7e+06
# Bond Actor Salary       6e+06
# Name: Dr. No, dtype: object

# %% [markdown]
# # Set Multiple Values in DF

# %%
bond['Actor'] == 'Sean Connery'
# Out:
# Film
# A View to a Kill                   False
# Casino Royale                      False
# Casino Royale                      False
# Diamonds Are Forever                True
# Die Another Day                    False
# Dr. No                             False
# For Your Eyes Only                 False
# From Russia with Love               True
# GoldenEye                          False
# Goldfinger                          True
# Licence to Kill                    False
# Live and Let Die                   False
# Moonraker                          False
# Never Say Never Again               True
# Octopussy                          False
# On Her Majesty's Secret Service    False
# Quantum of Solace                  False
# Skyfall                            False
# Spectre                            False
# The Living Daylights               False
# The Man with the Golden Gun        False
# The Spy Who Loved Me               False
# The World Is Not Enough            False
# ...

# %%
actor = bond['Actor'] == 'Sean Connery'

# %%
bond[actor]['Actor'] = 'Sire Sean Connery'
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
bond.loc[actor, 'Actor'] = 'Sir Sean Connery'

# %%
bond.head(4)
# Out:
#                       Year             Actor         Director  Box Office  \
# Film
# A View to a Kill      1985       Roger Moore        John Glen       275.2
# Casino Royale         2006      Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967       David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971  Sir Sean Connery     Guy Hamilton       442.5
#
#                       Budget  Bond Actor Salary Action
# Film
# A View to a Kill        54.5                9.1    NaN
# Casino Royale          145.3                3.3    NaN
# Casino Royale           85.0                NaN    NaN
# Diamonds Are Forever    34.7                5.8    NaN

# %%
bond
# Out:
#                                  Year             Actor            Director  \
# Film
# A View to a Kill                 1985       Roger Moore           John Glen
# Casino Royale                    2006      Daniel Craig     Martin Campbell
# Casino Royale                    1967       David Niven          Ken Hughes
# Diamonds Are Forever             1971  Sir Sean Connery        Guy Hamilton
# Die Another Day                  2002    Pierce Brosnan        Lee Tamahori
# Dr. No                           1962  Sir Sean Connery       Terence Young
# For Your Eyes Only               1981       Roger Moore           John Glen
# From Russia with Love            1963  Sir Sean Connery       Terence Young
# GoldenEye                        1995    Pierce Brosnan     Martin Campbell
# Goldfinger                       1964  Sir Sean Connery        Guy Hamilton
# Licence to Kill                  1989    Timothy Dalton           John Glen
# ...

# %% [markdown]
# # Rename Index Labels or Columns in a df

# %%
bond.rename(mapper = {'GoldenEye': 'Golden Eye', 
                      'The World Is Not Enough':'Best Bond Movie'})
bond.rename(mapper = {'GoldenEye': 'Golden Eye', 
                      'The World Is Not Enough':'Best Bond Movie'}, axis=0)
bond.rename(mapper = {'GoldenEye': 'Golden Eye', 
                      'The World Is Not Enough':'Best Bond Movie'}, axis='index')
bond.rename(mapper = {'GoldenEye': 'Golden Eye', 
                      'The World Is Not Enough':'Best Bond Movie'}, axis = 'rows')
bond.rename(index = {'GoldenEye': 'Golden Eye', 
                      'The World Is Not Enough':'Best Bond Movie'}, inplace = True)

# %%
bond.rename(mapper = {'Year': 'Release Date', 'Box Office': 'Revenue'}, axis = 1) #change column names
bond.rename(mapper = {'Year': 'Release Date', 'Box Office': 'Revenue'}, axis = 'columns') #change column names
bond.rename(columns = {'Year': 'Release Date', 'Box Office': 'Revenue'}) #change column names
bond.rename(columns = {'Year': 'Release Date', 'Box Office': 'Revenue'}, inplace=True) #change column names

# %%
bond.columns
# Out:
# Index(['Release Date', 'Actor', 'Director', 'Revenue', 'Budget',
#        'Bond Actor Salary', 'Action'],
#       dtype='object')

# %%
bond.columns = ['Year of Release', 'Actor', 'Director', 'Revenue', 'Cost',
       'Salary', 'Action'] # change column names directly

# %%
bond.head(4)
# Out:
#                       Year of Release             Actor         Director  \
# Film
# A View to a Kill                 1985       Roger Moore        John Glen
# Casino Royale                    2006      Daniel Craig  Martin Campbell
# Casino Royale                    1967       David Niven       Ken Hughes
# Diamonds Are Forever             1971  Sir Sean Connery     Guy Hamilton
#
#                       Revenue   Cost  Salary Action
# Film
# A View to a Kill        275.2   54.5     9.1    NaN
# Casino Royale           581.5  145.3     3.3    NaN
# Casino Royale           315.0   85.0     NaN    NaN
# Diamonds Are Forever    442.5   34.7     5.8    NaN

# %% [markdown]
# # Delete Rows or columns from a df

# %%
bond = pd.read_csv('jamesbond.csv', index_col = 'Film')
bond.sort_index(inplace=True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
bond.drop('A View to a Kill')
# Out:
#                                  Year           Actor            Director  \
# Film
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# ...

# %%
bond.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 26 entries, A View to a Kill to You Only Live Twice
# Data columns (total 6 columns):
# Year                 26 non-null int64
# Actor                26 non-null object
# Director             26 non-null object
# Box Office           26 non-null float64
# Budget               26 non-null float64
# Bond Actor Salary    18 non-null float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 2.0+ KB

# %%
bond.drop(['A View to a Kill', 'Die Another Day', 'Casino Royale']) #inplace = True
# Out:
#                                  Year           Actor            Director  \
# Film
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Dr. No                           1962    Sean Connery       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# Never Say Never Again            1983    Sean Connery      Irvin Kershner
# Octopussy                        1983     Roger Moore           John Glen
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# ...

# %%
bond.drop('Box Office', axis = 1)
# Out:
#                                  Year           Actor            Director  \
# Film
# A View to a Kill                 1985     Roger Moore           John Glen
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# ...

# %%
bond.drop(labels = ['Box Office', 'Bond Actor Salary', 'Actor'], axis = "columns")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-73c6e90247fd> in <module>
# ----> 1 bond.drop(labels = ['Box Office', 'Bond Actor Salary', 'Actor'], axis = "columns")
#
# NameError: name 'bond' is not defined

# %%
bond = pd.read_csv('jamesbond.csv')

# %%
bond = pd.read_csv('jamesbond.csv', index_col = 'Film')
bond.sort_index(inplace = True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
actor = bond.pop("Actor")

# %%
actor
# Out:
# Film
# A View to a Kill                      Roger Moore
# Casino Royale                        Daniel Craig
# Casino Royale                         David Niven
# Diamonds Are Forever                 Sean Connery
# Die Another Day                    Pierce Brosnan
# Dr. No                               Sean Connery
# For Your Eyes Only                    Roger Moore
# From Russia with Love                Sean Connery
# GoldenEye                          Pierce Brosnan
# Goldfinger                           Sean Connery
# Licence to Kill                    Timothy Dalton
# Live and Let Die                      Roger Moore
# Moonraker                             Roger Moore
# Never Say Never Again                Sean Connery
# Octopussy                             Roger Moore
# On Her Majesty's Secret Service    George Lazenby
# Quantum of Solace                    Daniel Craig
# Skyfall                              Daniel Craig
# Spectre                              Daniel Craig
# ...

# %% [markdown]
# # pop operator fetches a series

# %% [markdown]
# # Delete a column

# %%
del bond["Director"]

# %%
bond.head(4)
# Out:
#                       Year  Box Office  Budget  Bond Actor Salary
# Film
# A View to a Kill      1985       275.2    54.5                9.1
# Casino Royale         2006       581.5   145.3                3.3
# Casino Royale         1967       315.0    85.0                NaN
# Diamonds Are Forever  1971       442.5    34.7                5.8

# %%
del bond["Year"]

# %%
bond.head(4)
# Out:
#                       Box Office  Budget  Bond Actor Salary
# Film
# A View to a Kill           275.2    54.5                9.1
# Casino Royale              581.5   145.3                3.3
# Casino Royale              315.0    85.0                NaN
# Diamonds Are Forever       442.5    34.7                5.8

# %%
bond = pd.read_csv('jamesbond.csv', index_col = 'Film')
bond.sort_index(inplace = True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %% [markdown]
# # Create random samples

# %%
bond.sample()
# Out:
#                      Year           Actor            Director  Box Office  \
# Film
# Tomorrow Never Dies  1997  Pierce Brosnan  Roger Spottiswoode       463.2
#
#                      Budget  Bond Actor Salary
# Film
# Tomorrow Never Dies   133.9               10.0

# %%
bond.sample(n=5)
# Out:
#                          Year           Actor            Director  Box Office  \
# Film
# The World Is Not Enough  1999  Pierce Brosnan       Michael Apted       439.5
# From Russia with Love    1963    Sean Connery       Terence Young       543.8
# A View to a Kill         1985     Roger Moore           John Glen       275.2
# Thunderball              1965    Sean Connery       Terence Young       848.1
# Tomorrow Never Dies      1997  Pierce Brosnan  Roger Spottiswoode       463.2
#
#                          Budget  Bond Actor Salary
# Film
# The World Is Not Enough   158.3               13.5
# From Russia with Love      12.6                1.6
# A View to a Kill           54.5                9.1
# Thunderball                41.9                4.7
# Tomorrow Never Dies       133.9               10.0

# %% [markdown]
# Fraction of the total size

# %%
bond.sample(frac = .25)
# Out:
#                                  Year           Actor        Director  \
# Film
# Dr. No                           1962    Sean Connery   Terence Young
# Diamonds Are Forever             1971    Sean Connery    Guy Hamilton
# The Spy Who Loved Me             1977     Roger Moore   Lewis Gilbert
# Thunderball                      1965    Sean Connery   Terence Young
# On Her Majesty's Secret Service  1969  George Lazenby   Peter R. Hunt
# Never Say Never Again            1983    Sean Connery  Irvin Kershner
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# Dr. No                                448.8     7.0                0.6
# Diamonds Are Forever                  442.5    34.7                5.8
# The Spy Who Loved Me                  533.0    45.1                NaN
# Thunderball                           848.1    41.9                4.7
# On Her Majesty's Secret Service       291.5    37.3                0.6
# ...

# %%
bond.sample(n=3, axis=0) #rows
# Out:
#                  Year           Actor         Director  Box Office  Budget  \
# Film
# Die Another Day  2002  Pierce Brosnan     Lee Tamahori       465.4   154.2
# GoldenEye        1995  Pierce Brosnan  Martin Campbell       518.5    76.9
# Thunderball      1965    Sean Connery    Terence Young       848.1    41.9
#
#                  Bond Actor Salary
# Film
# Die Another Day               17.9
# GoldenEye                      5.1
# Thunderball                    4.7

# %%
bond.sample(n=3, axis=1) #columns
# Out:
#                                            Director  Bond Actor Salary  \
# Film
# A View to a Kill                          John Glen                9.1
# Casino Royale                       Martin Campbell                3.3
# Casino Royale                            Ken Hughes                NaN
# Diamonds Are Forever                   Guy Hamilton                5.8
# Die Another Day                        Lee Tamahori               17.9
# Dr. No                                Terence Young                0.6
# For Your Eyes Only                        John Glen                NaN
# From Russia with Love                 Terence Young                1.6
# GoldenEye                           Martin Campbell                5.1
# Goldfinger                             Guy Hamilton                3.2
# Licence to Kill                           John Glen                7.9
# Live and Let Die                       Guy Hamilton                NaN
# ...

# %%
bond.sample(n=3, axis="columns")
# Out:
#                                  Year  Bond Actor Salary  Budget
# Film
# A View to a Kill                 1985                9.1    54.5
# Casino Royale                    2006                3.3   145.3
# Casino Royale                    1967                NaN    85.0
# Diamonds Are Forever             1971                5.8    34.7
# Die Another Day                  2002               17.9   154.2
# Dr. No                           1962                0.6     7.0
# For Your Eyes Only               1981                NaN    60.2
# From Russia with Love            1963                1.6    12.6
# GoldenEye                        1995                5.1    76.9
# Goldfinger                       1964                3.2    18.6
# Licence to Kill                  1989                7.9    56.7
# Live and Let Die                 1973                NaN    30.8
# Moonraker                        1979                NaN    91.5
# ...

# %% [markdown]
# # The .nsmallest() and .nlargest() Methods

# %%
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
bond.sort_values("Box Office", ascending=False).head(3)
# Out:
#              Year         Actor       Director  Box Office  Budget  \
# Film
# Skyfall      2012  Daniel Craig     Sam Mendes       943.5   170.2
# Thunderball  1965  Sean Connery  Terence Young       848.1    41.9
# Goldfinger   1964  Sean Connery   Guy Hamilton       820.4    18.6
#
#              Bond Actor Salary
# Film
# Skyfall                   14.5
# Thunderball                4.7
# Goldfinger                 3.2

# %%
bond.nlargest(3, columns="Box Office")
# Out:
#              Year         Actor       Director  Box Office  Budget  \
# Film
# Skyfall      2012  Daniel Craig     Sam Mendes       943.5   170.2
# Thunderball  1965  Sean Connery  Terence Young       848.1    41.9
# Goldfinger   1964  Sean Connery   Guy Hamilton       820.4    18.6
#
#              Bond Actor Salary
# Film
# Skyfall                   14.5
# Thunderball                4.7
# Goldfinger                 3.2

# %%
bond.nsmallest(4, columns="Box Office")
# Out:
#                                  Year           Actor       Director  \
# Film
# Licence to Kill                  1989  Timothy Dalton      John Glen
# A View to a Kill                 1985     Roger Moore      John Glen
# On Her Majesty's Secret Service  1969  George Lazenby  Peter R. Hunt
# The Living Daylights             1987  Timothy Dalton      John Glen
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# Licence to Kill                       250.9    56.7                7.9
# A View to a Kill                      275.2    54.5                9.1
# On Her Majesty's Secret Service       291.5    37.3                0.6
# The Living Daylights                  313.5    68.8                5.2

# %%
bond.nlargest(3, columns="Budget")
# Out:
#                    Year         Actor      Director  Box Office  Budget  \
# Film
# Spectre            2015  Daniel Craig    Sam Mendes       726.7   206.3
# Quantum of Solace  2008  Daniel Craig  Marc Forster       514.2   181.4
# Skyfall            2012  Daniel Craig    Sam Mendes       943.5   170.2
#
#                    Bond Actor Salary
# Film
# Spectre                          NaN
# Quantum of Solace                8.1
# Skyfall                         14.5

# %%
bond["Box Office"].nlargest(8)
# Out:
# Film
# Skyfall                  943.5
# Thunderball              848.1
# Goldfinger               820.4
# Spectre                  726.7
# Casino Royale            581.5
# From Russia with Love    543.8
# Moonraker                535.0
# The Spy Who Loved Me     533.0
# Name: Box Office, dtype: float64

# %% [markdown]
# # Filter with the where method

# %%
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
bond["Actor"]
# Out:
# Film
# A View to a Kill                      Roger Moore
# Casino Royale                        Daniel Craig
# Casino Royale                         David Niven
# Diamonds Are Forever                 Sean Connery
# Die Another Day                    Pierce Brosnan
# Dr. No                               Sean Connery
# For Your Eyes Only                    Roger Moore
# From Russia with Love                Sean Connery
# GoldenEye                          Pierce Brosnan
# Goldfinger                           Sean Connery
# Licence to Kill                    Timothy Dalton
# Live and Let Die                      Roger Moore
# Moonraker                             Roger Moore
# Never Say Never Again                Sean Connery
# Octopussy                             Roger Moore
# On Her Majesty's Secret Service    George Lazenby
# Quantum of Solace                    Daniel Craig
# Skyfall                              Daniel Craig
# Spectre                              Daniel Craig
# ...

# %%
bond["Actor"] == "Sean Connery"
# Out:
# Film
# A View to a Kill                   False
# Casino Royale                      False
# Casino Royale                      False
# Diamonds Are Forever                True
# Die Another Day                    False
# Dr. No                              True
# For Your Eyes Only                 False
# From Russia with Love               True
# GoldenEye                          False
# Goldfinger                          True
# Licence to Kill                    False
# Live and Let Die                   False
# Moonraker                          False
# Never Say Never Again               True
# Octopussy                          False
# On Her Majesty's Secret Service    False
# Quantum of Solace                  False
# Skyfall                            False
# Spectre                            False
# The Living Daylights               False
# The Man with the Golden Gun        False
# The Spy Who Loved Me               False
# The World Is Not Enough            False
# ...

# %%
mask = bond["Actor"] == "Sean Connery"
bond[mask]
# Out:
#                        Year         Actor        Director  Box Office  Budget  \
# Film
# Diamonds Are Forever   1971  Sean Connery    Guy Hamilton       442.5    34.7
# Dr. No                 1962  Sean Connery   Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery   Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery    Guy Hamilton       820.4    18.6
# Never Say Never Again  1983  Sean Connery  Irvin Kershner       380.0    86.0
# Thunderball            1965  Sean Connery   Terence Young       848.1    41.9
# You Only Live Twice    1967  Sean Connery   Lewis Gilbert       514.2    59.9
#
#                        Bond Actor Salary
# Film
# Diamonds Are Forever                 5.8
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Never Say Never Again                NaN
# Thunderball                          4.7
# ...

# %%
bond.where(mask) #valid values without NaN
# Out:
#                                    Year         Actor        Director  \
# Film
# A View to a Kill                    NaN           NaN             NaN
# Casino Royale                       NaN           NaN             NaN
# Casino Royale                       NaN           NaN             NaN
# Diamonds Are Forever             1971.0  Sean Connery    Guy Hamilton
# Die Another Day                     NaN           NaN             NaN
# Dr. No                           1962.0  Sean Connery   Terence Young
# For Your Eyes Only                  NaN           NaN             NaN
# From Russia with Love            1963.0  Sean Connery   Terence Young
# GoldenEye                           NaN           NaN             NaN
# Goldfinger                       1964.0  Sean Connery    Guy Hamilton
# Licence to Kill                     NaN           NaN             NaN
# Live and Let Die                    NaN           NaN             NaN
# ...

# %%
bond["Box Office"] > 800
# Out:
# Film
# A View to a Kill                   False
# Casino Royale                      False
# Casino Royale                      False
# Diamonds Are Forever               False
# Die Another Day                    False
# Dr. No                             False
# For Your Eyes Only                 False
# From Russia with Love              False
# GoldenEye                          False
# Goldfinger                          True
# Licence to Kill                    False
# Live and Let Die                   False
# Moonraker                          False
# Never Say Never Again              False
# Octopussy                          False
# On Her Majesty's Secret Service    False
# Quantum of Solace                  False
# Skyfall                             True
# Spectre                            False
# The Living Daylights               False
# The Man with the Golden Gun        False
# The Spy Who Loved Me               False
# The World Is Not Enough            False
# ...

# %%
mask2 = bond.where(bond["Box Office"]>800)
bond.where(mask & mask2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-4b0b84532d46> in <module>
#       1 mask2 = bond.where(bond["Box Office"]>800)
# ----> 2 bond.where(mask & mask2)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in f(self, other, axis, level, fill_value)
#    1497             pass_op = op if axis in [0, "columns", None] else na_op
#    1498             return _combine_series_frame(
# -> 1499                 self, other, pass_op, fill_value=fill_value, axis=axis, level=level
#    1500             )
#    1501         else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in _combine_series_frame(self, other, func, fill_value, axis, level)
#    1386             return self._combine_match_index(other, func, level=level)
#    1387         else:
# ...

# %% [markdown]
# # The .query() method

# %%
bond.head(4)
# Out:
#                       Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill      1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale         2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale         1967   David Niven       Ken Hughes       315.0    85.0
# Diamonds Are Forever  1971  Sean Connery     Guy Hamilton       442.5    34.7
#
#                       Bond Actor Salary
# Film
# A View to a Kill                    9.1
# Casino Royale                       3.3
# Casino Royale                       NaN
# Diamonds Are Forever                5.8

# %%
bond.columns = [column_name.replace(" ", "_") for column_name in bond.columns]

# %%
bond.columns
# Out:
# Index(['Year', 'Actor', 'Director', 'Box_Office', 'Budget',
#        'Bond_Actor_Salary'],
#       dtype='object')

# %%
bond.query('Actor == "Sean Connery"')
# Out:
#                        Year         Actor        Director  Box_Office  Budget  \
# Film
# Diamonds Are Forever   1971  Sean Connery    Guy Hamilton       442.5    34.7
# Dr. No                 1962  Sean Connery   Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery   Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery    Guy Hamilton       820.4    18.6
# Never Say Never Again  1983  Sean Connery  Irvin Kershner       380.0    86.0
# Thunderball            1965  Sean Connery   Terence Young       848.1    41.9
# You Only Live Twice    1967  Sean Connery   Lewis Gilbert       514.2    59.9
#
#                        Bond_Actor_Salary
# Film
# Diamonds Are Forever                 5.8
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Never Say Never Again                NaN
# Thunderball                          4.7
# ...

# %%
bond.query("Box_Office>600")
# Out:
#              Year         Actor       Director  Box_Office  Budget  \
# Film
# Goldfinger   1964  Sean Connery   Guy Hamilton       820.4    18.6
# Skyfall      2012  Daniel Craig     Sam Mendes       943.5   170.2
# Spectre      2015  Daniel Craig     Sam Mendes       726.7   206.3
# Thunderball  1965  Sean Connery  Terence Young       848.1    41.9
#
#              Bond_Actor_Salary
# Film
# Goldfinger                 3.2
# Skyfall                   14.5
# Spectre                    NaN
# Thunderball                4.7

# %%
bond.query("Actor =='Roger Moore' or Director =='John Glen'")
# Out:
#                              Year           Actor       Director  Box_Office  \
# Film
# A View to a Kill             1985     Roger Moore      John Glen       275.2
# For Your Eyes Only           1981     Roger Moore      John Glen       449.4
# Licence to Kill              1989  Timothy Dalton      John Glen       250.9
# Live and Let Die             1973     Roger Moore   Guy Hamilton       460.3
# Moonraker                    1979     Roger Moore  Lewis Gilbert       535.0
# Octopussy                    1983     Roger Moore      John Glen       373.8
# The Living Daylights         1987  Timothy Dalton      John Glen       313.5
# The Man with the Golden Gun  1974     Roger Moore   Guy Hamilton       334.0
# The Spy Who Loved Me         1977     Roger Moore  Lewis Gilbert       533.0
#
#                              Budget  Bond_Actor_Salary
# Film
# A View to a Kill               54.5                9.1
# For Your Eyes Only             60.2                NaN
# ...

# %%
bond.query("Actor in ['Timthy Dalton', 'George Lazenby']")
# Out:
#                                  Year           Actor       Director  \
# Film
# On Her Majesty's Secret Service  1969  George Lazenby  Peter R. Hunt
#
#                                  Box_Office  Budget  Bond_Actor_Salary
# Film
# On Her Majesty's Secret Service       291.5    37.3                0.6

# %% [markdown]
# # A review of the .apply() method on single columns

# %%
bond.head(3)
# Out:
#                   Year         Actor         Director  Box_Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond_Actor_Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
def convert_to_string_and_add_millions(number):
    return str(number) + " MILLIONS!"

bond["Box_Office"].apply(convert_to_string_and_add_millions)
# Out:
# Film
# A View to a Kill                   275.2 MILLIONS!
# Casino Royale                      581.5 MILLIONS!
# Casino Royale                      315.0 MILLIONS!
# Diamonds Are Forever               442.5 MILLIONS!
# Die Another Day                    465.4 MILLIONS!
# Dr. No                             448.8 MILLIONS!
# For Your Eyes Only                 449.4 MILLIONS!
# From Russia with Love              543.8 MILLIONS!
# GoldenEye                          518.5 MILLIONS!
# Goldfinger                         820.4 MILLIONS!
# Licence to Kill                    250.9 MILLIONS!
# Live and Let Die                   460.3 MILLIONS!
# Moonraker                          535.0 MILLIONS!
# Never Say Never Again              380.0 MILLIONS!
# Octopussy                          373.8 MILLIONS!
# On Her Majesty's Secret Service    291.5 MILLIONS!
# Quantum of Solace                  514.2 MILLIONS!
# Skyfall                            943.5 MILLIONS!
# ...

# %%
bond = pd.read_csv('jamesbond.csv', index_col='Film')
bond.head(4)
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
# Thunderball            1965  Sean Connery  Terence Young       848.1    41.9
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Thunderball                          4.7

# %% [markdown]
# # The .apply() method with row values

# %%
def good_movie(row):
    actor = row[1]
    budget = row[4]
    if actor == 'Pierce Brosnan':
        return 'The Best'
    elif actor =='Roger Moore' and budget >40:
        return 'Enjoyable'
    else:
        return 'I have no clue'
bond.apply(good_movie, axis = "columns")
# Out:
# Film
# Dr. No                             I have no clue
# From Russia with Love              I have no clue
# Goldfinger                         I have no clue
# Thunderball                        I have no clue
# Casino Royale                      I have no clue
# You Only Live Twice                I have no clue
# On Her Majesty's Secret Service    I have no clue
# Diamonds Are Forever               I have no clue
# Live and Let Die                   I have no clue
# The Man with the Golden Gun        I have no clue
# The Spy Who Loved Me                    Enjoyable
# Moonraker                               Enjoyable
# For Your Eyes Only                      Enjoyable
# Never Say Never Again              I have no clue
# Octopussy                               Enjoyable
# A View to a Kill                        Enjoyable
# The Living Daylights               I have no clue
# Licence to Kill                    I have no clue
# GoldenEye                                The Best
# ...

# %% [markdown]
# # The .copy() method

# %%
bond.head(4)
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
# Thunderball            1965  Sean Connery  Terence Young       848.1    41.9
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Thunderball                          4.7

# %%
directors = bond["Director"]
directors.head(3)
# Out:
# Film
# Dr. No                   Terence Young
# From Russia with Love    Terence Young
# Goldfinger                Guy Hamilton
# Name: Director, dtype: object

# %%
directors
# Out:
# Film
# Dr. No                                  Terence Young
# From Russia with Love                   Terence Young
# Goldfinger                               Guy Hamilton
# Thunderball                             Terence Young
# Casino Royale                              Ken Hughes
# You Only Live Twice                     Lewis Gilbert
# On Her Majesty's Secret Service         Peter R. Hunt
# Diamonds Are Forever                     Guy Hamilton
# Live and Let Die                         Guy Hamilton
# The Man with the Golden Gun              Guy Hamilton
# The Spy Who Loved Me                    Lewis Gilbert
# Moonraker                               Lewis Gilbert
# For Your Eyes Only                          John Glen
# Never Say Never Again                  Irvin Kershner
# Octopussy                                   John Glen
# A View to a Kill                            John Glen
# The Living Daylights                        John Glen
# ...

# %%
directors["A View to a Kill"] = 'Mr John Glen'
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
directors.head(3)
# Out:
# Film
# Dr. No                   Terence Young
# From Russia with Love    Terence Young
# Goldfinger                Guy Hamilton
# Name: Director, dtype: object

# %%
directors
# Out:
# Film
# Dr. No                                  Terence Young
# From Russia with Love                   Terence Young
# Goldfinger                               Guy Hamilton
# Thunderball                             Terence Young
# Casino Royale                              Ken Hughes
# You Only Live Twice                     Lewis Gilbert
# On Her Majesty's Secret Service         Peter R. Hunt
# Diamonds Are Forever                     Guy Hamilton
# Live and Let Die                         Guy Hamilton
# The Man with the Golden Gun              Guy Hamilton
# The Spy Who Loved Me                    Lewis Gilbert
# Moonraker                               Lewis Gilbert
# For Your Eyes Only                          John Glen
# Never Say Never Again                  Irvin Kershner
# Octopussy                                   John Glen
# A View to a Kill                         Mr John Glen
# The Living Daylights                        John Glen
# ...

# %%
bond.head(3)
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2

# %%
bond
# Out:
#                                  Year           Actor            Director  \
# Film
# Dr. No                           1962    Sean Connery       Terence Young
# From Russia with Love            1963    Sean Connery       Terence Young
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Thunderball                      1965    Sean Connery       Terence Young
# Casino Royale                    1967     David Niven          Ken Hughes
# You Only Live Twice              1967    Sean Connery       Lewis Gilbert
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# The Man with the Golden Gun      1974     Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977     Roger Moore       Lewis Gilbert
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# ...

# %% [markdown]
# Value change in the original df as well

# %% [markdown]
# Now create a separate copy in that way the value will not be affecting the df

# %%
directors = bond['Director'].copy() #brand new unique series object
directors.head(3)
# Out:
# Film
# Dr. No                   Terence Young
# From Russia with Love    Terence Young
# Goldfinger                Guy Hamilton
# Name: Director, dtype: object

# %%
directors['A View to a Kill'] = 'John Glen'

# %%
directors
# Out:
# Film
# Dr. No                                  Terence Young
# From Russia with Love                   Terence Young
# Goldfinger                               Guy Hamilton
# Thunderball                             Terence Young
# Casino Royale                              Ken Hughes
# You Only Live Twice                     Lewis Gilbert
# On Her Majesty's Secret Service         Peter R. Hunt
# Diamonds Are Forever                     Guy Hamilton
# Live and Let Die                         Guy Hamilton
# The Man with the Golden Gun              Guy Hamilton
# The Spy Who Loved Me                    Lewis Gilbert
# Moonraker                               Lewis Gilbert
# For Your Eyes Only                          John Glen
# Never Say Never Again                  Irvin Kershner
# Octopussy                                   John Glen
# A View to a Kill                            John Glen
# The Living Daylights                        John Glen
# ...

# %%
bond
# Out:
#                                  Year           Actor            Director  \
# Film
# Dr. No                           1962    Sean Connery       Terence Young
# From Russia with Love            1963    Sean Connery       Terence Young
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Thunderball                      1965    Sean Connery       Terence Young
# Casino Royale                    1967     David Niven          Ken Hughes
# You Only Live Twice              1967    Sean Connery       Lewis Gilbert
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# The Man with the Golden Gun      1974     Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977     Roger Moore       Lewis Gilbert
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# ...
